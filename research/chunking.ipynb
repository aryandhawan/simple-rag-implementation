# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

loader = DirectoryLoader(path="synthetic_corpus/", glob="**/*.md", loader_cls=TextLoader,loader_kwargs={"encoding": "utf8"})

documents = loader.load()

print(f"Loaded {len(documents)} documents")
print(documents[0].metadata)
print(documents[0].page_content[:200])
# Out:
# Loaded 32 documents
# {'source': 'synthetic_corpus\\attention_mechanisms.md'}
# # Attention Mechanisms
#
# Attention mechanisms allow neural networks to dynamically focus on different parts of their input when producing each element of their output. Rather than compressing an entire

# %%
# %pwd
import os
os.chdir("C:/Users/Aryan/Desktop/Projects/RAG_projects/bot_project")
# %pwd
# Out:
# 'C:\\Users\\Aryan\\Desktop\\Projects\\RAG_projects\\bot_project'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(documents)

print(f"Created {len(chunks)} chunks from {len(documents)} documents")
print(chunks[0].metadata)
print(chunks[0].page_content)
# Out:
# Created 160 chunks from 32 documents
# {'source': 'synthetic_corpus\\attention_mechanisms.md'}
# # Attention Mechanisms
#
# Attention mechanisms allow neural networks to dynamically focus on different parts of their input when producing each element of their output. Rather than compressing an entire input sequence into a single fixed-size vector, attention enables the model to selectively weight the importance of each input element at each step of computation. This idea was first applied to sequence-to-sequence models in 2015 and later became the central building block of the Transformer architecture.

# %%
class ConfigurationManager:
    def __init__(self, config_path: Path='config/config.yaml'):
        self.config_path = read_yaml(config_path)
        
    
    def get_chunking_config(self)-> ChunkingConfig:
        
        # Create and return a ChunkingConfig instance
        return ChunkingConfig(
            root_dir=self.config_path.root_dir,
            chunk_size=self.config_path.chunk_size,
            chunk_overlap=self.config_path.chunk_overlap
        )

# %%
from pathlib import Path
from entity.config_entity import ChunkingConfig
from config.configuration import ConfigurationManager,read_yaml,create_directories
