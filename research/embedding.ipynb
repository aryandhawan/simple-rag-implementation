# %%
"Hello"
# Out:
# 'Hello'

# %%
# %pwd
import os
os.chdir("C:/Users/Aryan/Desktop/Projects/RAG_projects/bot_project")
# %pwd
# Out:
# 'C:\\Users\\Aryan\\Desktop\\Projects\\RAG_projects\\bot_project'

# %%
from entity.config_entity import EmbeddingConfig
from pathlib import Path
from config.configuration import ConfigurationManager,create_directories

# %%
def get_embedding_config(self)-> EmbeddingConfig:
        config=self.config.embedding
        create_directories([Path(config.root_dir)], verbose=True)
        # Create and return a EmbeddingConfig instance
        return EmbeddingConfig(
            root_dir=Path(config.root_dir),
            model_name=config.model_name,
            vector_store_path=config.vector_store_path
        )

# %%
from config.configuration import read_yaml,create_directories

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory="artifacts/embedding/vector_store",
    collection_name="ai_ml_concepts"
)

print(f"Embedded {len(chunks)} chunks into vector store")
